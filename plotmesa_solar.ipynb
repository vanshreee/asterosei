# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt


file = "/Users/vanshree/asterosei/mesa_outputs/simplex_results_solarcalib1.data"
#file = "/home/sarek2/vanshree/asterosei/mesa/star/test_suite/papayu_erica/LOGS/pgstar.dat"
output = pd.read_csv(file, sep = '\s+', comment = '\n', header = 1, index_col = False)#file, sep='\s+',header =1)#,comment = '\n')#,index_col = False)#, index_col = False)#sep = '\s+')#, comment = '\n', header = 1, index_col = False)
output = output.drop(len(output)-1, axis = 0)
output
# Out:
#     sample                    chi2                mass  \
# 0      404      6.8024491451661691  1.0000000000000000
# 1      413      6.8024491456143146  1.0000000000000000
# 2      372      6.8024491548793939  1.0000000000000000
# 3      383      6.8024491601773969  1.0000000000000000
# 4      432      6.8024491705315633  1.0000000000000000
# ..     ...                     ...                 ...
# 431      4  7.4543173550416850E+02  1.0000000000000000
# 432      1  7.5385026215558958E+02  1.0000000000000000
# 433      8  9.9463090072454531E+02  1.0000000000000000
# 434      5  9.9564907858207141E+02  1.0000000000000000
# 435      3  9.9873408585351888E+02  1.0000000000000000
#
#                      init_Y                init_FeH               alpha  \
# 0    2.8190289870777402E-01  1.1118743838085304E-01  1.8969610204341603
# 1    2.8190289845817440E-01  1.1118743912060550E-01  1.8969610137351272
# 2    2.8190289906015314E-01  1.1118743717547358E-01  1.8969610298841260
# ...

# %%
# %matplotlib inline
plt.figure(figsize = (10,10))
plt.plot(output['sample'].astype('int64'), output['alpha'].astype('float'), marker = 'o', ls = ' ')
plt.ylabel('Alpha',fontsize = 15)
plt.xlabel('Samples',fontsize = 15)
plt.title('Sample Number vs. Alpha',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sample Number vs. Alpha')

# %%
plt.figure(figsize = (10,10))
plt.plot(output['sample'].astype('int'), output['chi2'].astype('float64'), marker = 'o', ls = ' ')
plt.ylabel(r'$\chi^2$',fontsize = 15)
plt.xlabel('Samples',fontsize = 15)
plt.title(r'Sample Number vs. $\chi^2$',fontsize = 20)
#plt.ylim(output['chi2'].astype('float').min() - 5, 110)
# Out:
# Text(0.5, 1.0, 'Sample Number vs. $\\chi^2$')

# %%
plt.figure(figsize = (10,10))
plt.plot(output['sample'].astype('int64'), output['mass'].astype('float'), marker = 'o', ls = ' ')
plt.ylabel('Mass',fontsize = 15)
plt.xlabel('Samples',fontsize = 15)
plt.title('Sample Number vs. Mass',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sample Number vs. Mass')

# %%
plt.figure(figsize = (10,10))
plt.plot(output['sample'].astype('int64'), output['Teff'].astype('float'), marker = 'o', ls = ' ')
plt.ylabel(r'T$_{eff}$',fontsize = 15)
plt.xlabel('Samples',fontsize = 15)
plt.title(r'Sample Number vs. T$_{eff}$',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sample Number vs. T$_{eff}$')

# %%
plt.figure(figsize = (10,10))
plt.plot(output['sample'].astype('int64'), output['solar_cs_rms'].astype('float'), marker = 'o', ls = ' ')
plt.ylabel(r'solar_cs_rms',fontsize = 15)
plt.xlabel('Samples',fontsize = 15)
plt.title(r'Sample Number vs. solar_cs_rms',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sample Number vs. solar_cs_rms')

# %%
plt.figure(figsize = (10,10))
plt.plot(output['sample'].astype('int64'), output['logg'].astype('float'), marker = 'o', ls = ' ')
plt.ylabel(r'logg',fontsize = 15)
plt.xlabel('Samples',fontsize = 15)
plt.title(r'Sample Number vs. logg',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sample Number vs. logg')

# %%
# plt.figure(figsize = (10,10))
# plt.plot(output['sample'].astype('int64'), output['logR'].astype('float'), marker = 'o', ls = ' ')
# plt.ylabel(r'logR',fontsize = 15)
# plt.xlabel('Samples',fontsize = 15)
# plt.title(r'Sample Number vs. logR',fontsize = 20)

# %%
plt.figure(figsize = (10,10))
plt.plot(output['sample'].astype('int64'), output['age'].astype('float'), marker = 'o', ls = ' ')
plt.ylabel('Age',fontsize = 15)
plt.xlabel('Samples',fontsize = 15)
plt.title('Sample Number vs. Age',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sample Number vs. Age')

# %%
print (output['age'])
# print (output['age'].astype('float'))
# Out:
# 0      4.6100000000000010E+09
# 1      4.6100000000000000E+09
# 2      4.6100000000000010E+09
# 3      4.6100000000000000E+09
# 4      4.6100000000000000E+09
#                 ...
# 431    4.6100000000000000E+09
# 432    4.6100000000000000E+09
# 433    4.6269512812460556E+09
# 434    4.7885001861254148E+09
# 435    4.6119932611587458E+09
# Name: age, Length: 436, dtype: object

# %%
plt.figure(figsize = (10,10))
plt.plot(output['sample'].astype('int64'), output['init_FeH'].astype('float'), marker = 'o', ls = ' ')
plt.ylabel(r'Intial $\frac{Fe}{H}$',fontsize = 15)
plt.xlabel('Samples',fontsize = 15)
plt.title(r'Sample Number vs. Intial $\frac{Fe}{H}$',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sample Number vs. Intial $\\frac{Fe}{H}$')

# %%
plt.figure(figsize = (10,10))
plt.plot(output['sample'].astype('int64'), output['logR'].astype('float'), marker = 'o', ls = ' ')
plt.ylabel('log(radius)', fontsize = 15)
plt.xlabel('Samples', fontsize = 15)
plt.title('Sample Number vs. log(radius)', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Sample Number vs. log(radius)')

# %%
fig, axes = plt.subplots(5, 2, figsize = (22, 40))

axes[0,0].plot(output['sample'].astype('int64'), output['alpha'].astype('float'), marker = 'o', ls = ' ')
axes[0,0].set_ylabel(r'$\alpha$', fontsize = 20)
#axes[0,0].set_xlabel('Sample Number', fontsize = 20)
axes[0,0].set_title(r'$\alpha$ Evolution', fontsize = 20)

axes[0,1].plot(output['sample'].astype('int64'), output['chi2'].astype('float'), marker = 'o', ls = ' ')
axes[0,1].set_ylabel(r'$\chi^2$', fontsize = 20)
axes[0,1].set_title(r'$\chi^2$ Evolution', fontsize = 20)

axes[1,0].plot(output['sample'].astype('int64'), output['mass'].astype('float'), marker = 'o', ls = ' ')
axes[1,0].set_ylabel('Mass', fontsize = 20)
axes[1,0].set_title('Mass Evolution', fontsize = 20)

axes[1,1].plot(output['sample'].astype('int64'), output['Teff'].astype('float'), marker = 'o', ls = ' ')
axes[1,1].set_ylabel(r'T$_{eff}$', fontsize = 20)
axes[1,1].set_title(r'T$_{eff}$ Evolution', fontsize = 20)

axes[2,0].plot(output['sample'].astype('int64'), output['solar_cs_rms'].astype('float'), marker = 'o', ls = ' ')
axes[2,0].set_ylabel(r'solar_cs_rms', fontsize = 20)
axes[2,0].set_title(r'solar_cs_rms Evolution', fontsize = 20)

# axes[2,1].plot(output['sample'].astype('int64'), output['chi2_spectro'].astype('float'), marker = 'o', ls = ' ')
# axes[2,1].set_ylabel(r'$\chi_{spectro}^2$', fontsize = 20)
# axes[2,1].set_title(r'$\chi_{spectro}^2$ Evolution', fontsize = 20)

axes[3,0].plot(output['sample'].astype('int64'), output['logg'].astype('float'), marker = 'o', ls = ' ')
axes[3,0].set_ylabel(r'logg', fontsize = 20)
axes[3,0].set_title(r'logg Evolution', fontsize = 20)

axes[3,1].plot(output['sample'].astype('int64'), output['age'].astype('float'), marker = 'o', ls = ' ')
axes[3,1].set_ylabel('Age', fontsize = 20)
axes[3,1].set_title('Age Evolution', fontsize = 20)

axes[4,0].plot(output['sample'].astype('int64'), output['init_FeH'].astype('float'), marker = 'o', ls = ' ')
axes[4,0].set_ylabel(r'$\frac{Fe}{H}$', fontsize = 20)
axes[4,0].set_title(r'$\frac{Fe}{H}$ Evolution', fontsize = 20)

axes[4,1].plot(output['sample'].astype('int64'), output['logR'].astype('float'), marker = 'o', ls = ' ')
axes[4,1].set_ylabel('log(Radius)', fontsize = 20)
axes[4,1].set_title('log(Radius) Evolution', fontsize = 20)
plt.text(-0.1,-3.75, "Sample Number", fontsize = 20, transform=axes[1][1].transAxes, horizontalalignment = 'center')
# Out:
# Text(-0.1, -3.75, 'Sample Number')

# %%
# fig, axes = plt.subplots(2, 3, figsize = (20, 15))
# axes[0,0].plot(output['sample'].astype('int64'), output['l1_freq_1'].astype('float'), marker = 'o', ls = ' ', label = 'original frequency')
# axes[0,0].plot(output['sample'].astype('int64'), output['l1_freq_corr_1'].astype('float'), marker = 'o', ls = ' ', label = 'corrected frequency')
# axes[0,0].legend(fontsize = 12)

# axes[0,1].plot(output['sample'].astype('int64'), output['l1_freq_2'].astype('float'), marker = 'o', ls = ' ')
# axes[0,1].plot(output['sample'].astype('int64'), output['l1_freq_corr_2'].astype('float'), marker = 'o', ls = ' ')

# axes[0,2].plot(output['sample'].astype('int64'), output['l1_freq_3'].astype('float'), marker = 'o', ls = ' ')
# axes[0,2].plot(output['sample'].astype('int64'), output['l1_freq_corr_3'].astype('float'), marker = 'o', ls = ' ')

# axes[1,0].plot(output['sample'].astype('int64'), output['l1_freq_4'].astype('float'), marker = 'o', ls = ' ')
# axes[1,0].plot(output['sample'].astype('int64'), output['l1_freq_corr_4'].astype('float'), marker = 'o', ls = ' ')

# axes[1,1].plot(output['sample'].astype('int64'), output['l1_freq_5'].astype('float'), marker = 'o', ls = ' ')
# axes[1,1].plot(output['sample'].astype('int64'), output['l1_freq_corr_5'].astype('float'), marker = 'o', ls = ' ')

# axes[1,2].plot(output['sample'].astype('int64'), output['l1_freq_6'].astype('float'), marker = 'o', ls = ' ')
# axes[1,2].plot(output['sample'].astype('int64'), output['l1_freq_corr_6'].astype('float'), marker = 'o', ls = ' ')

# plt.text(-0.20,0.15, r"Frequency (in $\mu$Hz)", fontsize = 20, rotation = 90, transform=axes[0][0].transAxes, horizontalalignment = 'center')
# plt.text(0.5,1.15, r"$\ell = 1$: Frequency & Corrected Frequency", fontsize = 20, transform=axes[0][1].transAxes, horizontalalignment = 'center')
# plt.text(0.5,-0.15, "Sample Number", fontsize = 20, transform=axes[1][1].transAxes, horizontalalignment = 'center')

# %%
# fig, axes = plt.subplots(2, 3, figsize = (20, 15))
# axes[0,0].plot(output['sample'].astype('int64'), output['l0_freq_1'].astype('float'), marker = 'o', ls = ' ', label = 'original frequency')
# axes[0,0].plot(output['sample'].astype('int64'), output['l0_freq_corr_1'].astype('float'), marker = 'o', ls = ' ', label = 'corrected frequency')
# axes[0,0].legend(fontsize = 12)

# axes[0,1].plot(output['sample'].astype('int64'), output['l0_freq_2'].astype('float'), marker = 'o', ls = ' ')
# axes[0,1].plot(output['sample'].astype('int64'), output['l0_freq_corr_2'].astype('float'), marker = 'o', ls = ' ')

# axes[0,2].plot(output['sample'].astype('int64'), output['l0_freq_3'].astype('float'), marker = 'o', ls = ' ')
# axes[0,2].plot(output['sample'].astype('int64'), output['l0_freq_corr_3'].astype('float'), marker = 'o', ls = ' ')

# axes[1,0].plot(output['sample'].astype('int64'), output['l0_freq_4'].astype('float'), marker = 'o', ls = ' ')
# axes[1,0].plot(output['sample'].astype('int64'), output['l0_freq_corr_4'].astype('float'), marker = 'o', ls = ' ')

# axes[1,1].plot(output['sample'].astype('int64'), output['l0_freq_5'].astype('float'), marker = 'o', ls = ' ')
# axes[1,1].plot(output['sample'].astype('int64'), output['l0_freq_corr_5'].astype('float'), marker = 'o', ls = ' ')

# axes[1,2].axis('off')

# plt.text(-0.20,0.15, r"Frequency (in $\mu$Hz)", fontsize = 20, rotation = 90, transform=axes[0][0].transAxes, horizontalalignment = 'center')
# plt.text(0.5,1.15, r"$\ell = 0$: Frequency & Corrected Frequency", fontsize = 20, transform=axes[0][1].transAxes, horizontalalignment = 'center')
# plt.text(0.5,-0.15, "Sample Number", fontsize = 20, transform=axes[1][1].transAxes, horizontalalignment = 'center')

# %%
# fig, axes = plt.subplots(2, 2, figsize = (15, 15))
# axes[0,0].plot(output['sample'].astype('int64'), output['l2_freq_1'].astype('float'), marker = 'o', ls = ' ', label = 'original frequency')
# axes[0,0].plot(output['sample'].astype('int64'), output['l2_freq_corr_1'].astype('float'), marker = 'o', ls = ' ', label = 'corrected frequency')
# axes[0,0].legend(fontsize = 12)

# axes[0,1].plot(output['sample'].astype('int64'), output['l2_freq_2'].astype('float'), marker = 'o', ls = ' ')
# axes[0,1].plot(output['sample'].astype('int64'), output['l2_freq_corr_2'].astype('float'), marker = 'o', ls = ' ')

# axes[1,0].plot(output['sample'].astype('int64'), output['l2_freq_3'].astype('float'), marker = 'o', ls = ' ')
# axes[1,0].plot(output['sample'].astype('int64'), output['l2_freq_corr_3'].astype('float'), marker = 'o', ls = ' ')

# axes[1,1].plot(output['sample'].astype('int64'), output['l2_freq_4'].astype('float'), marker = 'o', ls = ' ')
# axes[1,1].plot(output['sample'].astype('int64'), output['l2_freq_corr_4'].astype('float'), marker = 'o', ls = ' ')

# plt.text(-0.20,0.15, r"Frequency (in $\mu$Hz)", fontsize = 20, rotation = 90, transform=axes[0][0].transAxes, horizontalalignment = 'center')
# plt.text(-0.1,1.15, r"$\ell = 2$: Frequency & Corrected Frequency", fontsize = 20, transform=axes[0][1].transAxes, horizontalalignment = 'center')
# plt.text(-0.1,-0.15, "Sample Number", fontsize = 20, transform=axes[1][1].transAxes, horizontalalignment = 'center')

# %%
# OUTPUTS 
print("Papayu params:")

# alpha
mean_alpha = np.mean(output['alpha'].astype('float'))
print("alpha = ", mean_alpha)
                     
# Chi^2 
mean_chi2 = np.mean(output['chi2'].astype('float'))
print("chi2 = ",mean_chi2)
                     
# solar_cs_rms 
mean_solar_cs_rms = np.mean(output['solar_cs_rms'].astype('float'))
print("solar_cs_rms = ",mean_solar_cs_rms)
                     
# # Chi^2 spectral 
# mean_chi2_spectro = np.mean(output['chi2_spectro'].astype('float'))   
# print("chi2_spectro = ",mean_chi2_spectro)

# Mass
mean_mass = np.mean(output['mass'].astype('float'))
print("mass = ",mean_mass, "M_sun")

# Age
mean_age = np.mean(output['age'].astype('float'))
mean_age_gyr = mean_age*(10**-9)
print("Age = ",mean_age_gyr, "Gyr")

# Teff
mean_teff = np.mean(output['Teff'].astype('float'))
print("Teff = ",mean_teff, "K")

# logg
mean_logg = np.mean(output['logg'].astype('float'))
print("logg = ",mean_logg, ".")

# FeH
mean_feh = np.mean(output['init_FeH'].astype('float'))
print("FeH = ",mean_feh, "dex")
                     
# log(Radius)
mean_logr = np.mean(output['logR'].astype('float'))
mean_radius = 10**mean_logr
# print("log(radius) = ",mean_logr)
print("Radius = ",mean_radius,"R_sun")
# Out:
# Papayu params:
# alpha =  1.8969888970474846
# chi2 =  25.112416391382396
# solar_cs_rms =  0.0012860439703232928
# mass =  1.0 M_sun
# Age =  4.610452854881951 Gyr
# Teff =  5774.892625550746 K
# logg =  4.437984422834104 .
# FeH =  0.10728933794103417 dex
# Radius =  0.999890553273959 R_sun

# %%
# ## MODEL FREQS

# #####################################
# # l0 modes (qty = five)
# #####################################
#     # og
# l01 = np.mean(output['l0_freq_1'].astype('float'))
# l02 = np.mean(output['l0_freq_2'].astype('float'))
# l03 = np.mean(output['l0_freq_3'].astype('float'))
# l04 = np.mean(output['l0_freq_4'].astype('float'))
# l05 = np.mean(output['l0_freq_5'].astype('float'))

#     # corrected for shift
# l0c1 = np.mean(output['l0_freq_corr_1'].astype('float'))
# l0c2 = np.mean(output['l0_freq_corr_2'].astype('float'))
# l0c3 = np.mean(output['l0_freq_corr_3'].astype('float'))
# l0c4 = np.mean(output['l0_freq_corr_4'].astype('float'))
# l0c5 = np.mean(output['l0_freq_corr_5'].astype('float'))

#     #mean freq diff
# l01diff = l01-l0c1
# l02diff = l02-l0c2
# l03diff = l03-l0c3
# l04diff = l04-l0c4
# l05diff = l05-l0c5

# l0diffavg = (l01diff+l02diff+l03diff+l04diff+l05diff)/5
#     # list of l = 0 modes
# l0og = np.array([l01,l02,l03,l04,l05])
# l0corr = np.array([l0c1,l0c2,l0c3,l0c4,l0c5])
# l0diff = np.array([l01diff,l02diff,l03diff,l04diff,l05diff])

# #####################################
# # l1 modes (qty = six)
# #####################################
#     # og
# l11 = np.mean(output['l1_freq_1'].astype('float'))
# l12 = np.mean(output['l1_freq_2'].astype('float'))
# l13 = np.mean(output['l1_freq_3'].astype('float'))
# l14 = np.mean(output['l1_freq_4'].astype('float'))
# l15 = np.mean(output['l1_freq_5'].astype('float'))
# l16 = np.mean(output['l1_freq_6'].astype('float'))

#     # corrected for shift
# l1c1 = np.mean(output['l1_freq_corr_1'].astype('float'))
# l1c2 = np.mean(output['l1_freq_corr_2'].astype('float'))
# l1c3 = np.mean(output['l1_freq_corr_3'].astype('float'))
# l1c4 = np.mean(output['l1_freq_corr_4'].astype('float'))
# l1c5 = np.mean(output['l1_freq_corr_5'].astype('float'))
# l1c6 = np.mean(output['l1_freq_corr_6'].astype('float'))

#     #mean freq diff
# l11diff = l11-l1c1
# l12diff = l12-l1c2
# l13diff = l13-l1c3
# l14diff = l14-l1c4
# l15diff = l15-l1c5
# l16diff = l16-l1c6

# l1diffavg = (l11diff+l12diff+l13diff+l14diff+l15diff+l16diff)/6
#     # list of l = 1 modes
# l1og = np.array([l11,l12,l13,l14,l15,l16])
# l1corr = np.array([l1c1,l1c2,l1c3,l1c4,l1c5,l1c6])
# l1diff = np.array([l11diff,l12diff,l13diff,l14diff,l15diff,l16diff])

# #####################################
# # l2 modes (qty = four)
# #####################################
#     # og
# l21 = np.mean(output['l2_freq_1'].astype('float'))
# l22 = np.mean(output['l2_freq_2'].astype('float'))
# l23 = np.mean(output['l2_freq_3'].astype('float'))
# l24 = np.mean(output['l2_freq_4'].astype('float'))
#     # corrected for shift
# l2c1 = np.mean(output['l2_freq_corr_1'].astype('float'))
# l2c2 = np.mean(output['l2_freq_corr_2'].astype('float'))
# l2c3 = np.mean(output['l2_freq_corr_3'].astype('float'))
# l2c4 = np.mean(output['l2_freq_corr_4'].astype('float'))
#     #mean l2 freq diff
# l21diff = l21-l2c1
# l22diff = l22-l2c2
# l23diff = l23-l2c3
# l24diff = l24-l2c4
# l2diffavg = (l21diff+l22diff+l23diff+l24diff)/4
#     # list of l = 2 modes
# l2og = np.array([l21,l22,l23,l24])
# l2corr = np.array([l2c1,l2c2,l2c3,l2c4])
# l2diff = np.array([l21diff,l22diff,l23diff,l24diff])

# #############################
# ######## PRINT #############################
# #############################

# print("There is a frequency offest in the modelled mesa frequencies. Corrected frequencies (given by corr) are outputted along with uncorrected (orig) ones. The corrected frequencies are very close to the frequencies obtained through Peak Bagging")

# print("--------------------------------------------------------------------------------------------------")

# print("l = 0 modes")

# print("--------------------------------------------------------------------------------------------------")

# print ("orig = ",l0og, "microHz")
# print("corr = ",l0corr, "microHz")
# print("diff = ",l0diff,"microHz")
# print("avg radial diff = ", l0diffavg, "microHz")

# print("--------------------------------------------------------------------------------------------------")

# print("l = 1 modes")

# print("--------------------------------------------------------------------------------------------------")

# print ("orig = ",l1og, "microHz")
# print("corr = ",l1corr, "microHz")
# print("diff = ",l1diff,"microHz")
# print("avg dipole diff = ", l1diffavg, "microHz")

# print("--------------------------------------------------------------------------------------------------")

# print("l = 2 modes")

# print("--------------------------------------------------------------------------------------------------")

# print ("orig = ",l2og, "microHz")
# print("corr = ",l2corr, "microHz")
# print("diff = ",l2diff,"microHz")
# print("avg quadrapole diff = ", l2diffavg, "microHz")

# print("--------------------------------------------------------------------------------------------------")
# print("--------------------------------------------------------------------------------------------------")

# freq_corr = (l0diffavg+l1diffavg+l2diffavg)/3
# print("avg frequency correction = ",freq_corr,"micro Hz")

# print("delta_nu accounting for the correction factor is",mean_dnu-freq_corr," micro Hz")
# print("This matches the delta_nu from echelle, which is 97.73 +/- 0.3 micro Hz")


# ###################################

# lcorr = np.concatenate([l0corr,l1corr,l2corr],axis=None)
# log = np.concatenate([l0og,l1og,l2og],axis=None)
# ldiffcorr = lcorr-lcorr
# ldiffog = lcorr-log

# # print(l0corr)
# # print(l1corr)
# # print(l2corr)
# # print(lcorr)

# log = plt.scatter(log,ldiffog,marker='o',facecolor='black',s=20, label='Uncorrected')
# lcorr = plt.scatter(lcorr,ldiffcorr,marker='o',facecolor='white',edgecolor='black',s=20, label='Corrected')

# # plt.ylim([1650,2400])
# plt.xlabel('Frequency_obs')
# plt.ylabel('f_obs-f_mod')

# # plt.title('Frequencies from PeakBagging and MESA Modelling')
# # #         l1echobs = ([],[],color='fuchsia', marker='^',markersize=2, label='Observed l = 1')
# # #         l2echobs = mlines.Line2D([], [], color='springgreen', marker='s',markersize=2, label='Observed l = 2')
# # #         l0echobs = mlines.Line2D([], [], color='dodgerblue', marker='o',markersize=2, label='Observed l = 0')
# # #         l1echobs = mlines.Line2D([], [], color='fuchsia', marker='.',
# # #                           markersize=2, label='Observed l = 1')
        
# plt.legend(handles=[log,lcorr])#,loc="lower left", mode = "expand", ncol = 3)
# # #                 plt.legend(handles=(l1echobs,l2echobs,l0echobs))
# plt.show()

# %%
#@@@@@@@@@
#  observed l=0 modes to match to model
#          nl0 = 5
#          l0_obs(1) = 1879.04d0
#          l0_obs(2) = 1978.84d0
#          l0_obs(3) = 2075.79d0
#          l0_obs(4) = 2172.32d0
#          l0_obs(5) = 2269.80d0
#          l0_obs_sigma(1) = 0.24d0
#          l0_obs_sigma(2) = 0.27d0
#          l0_obs_sigma(3) = 0.24d0
#          l0_obs_sigma(4) = 0.30d0
#          l0_obs_sigma(5) = 0.14d0
   
#       ! observed l=1 modes to match to model
#          nl1 = 6
#          l1_obs(1) = 1828.88d0
#          l1_obs(2) = 1926.45d0
#          l1_obs(3) = 2023.69d0
#          l1_obs(4) = 2121.72d0
#          l1_obs(5) = 2218.08d0
#          l1_obs(6) = 2316.16d0
#          l1_obs_sigma(1) = 0.22d0
#          l1_obs_sigma(2) = 0.21d0
#          l1_obs_sigma(3) = 0.19d0
#          l1_obs_sigma(4) = 0.14d0
#          l1_obs_sigma(5) = 0.18d0
#          l1_obs_sigma(6) = 0.22d0
   
#       ! observed l=2 modes to match to model
#          nl2 = 4
#          l2_obs(1) = 1873.37d0
#          l2_obs(2) = 1972.11d0
#          l2_obs(3) = 2166.12d0
#          l2_obs(4) = 2263.93d0
#          l2_obs_sigma(1) = 0.13d0
#          l2_obs_sigma(2) = 0.17d0
#          l2_obs_sigma(3) = 0.20d0
#          l2_obs_sigma(4) = 0.17d0
